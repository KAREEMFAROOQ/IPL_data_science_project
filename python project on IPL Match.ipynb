# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
ipl=pd.read_csv('F:\Match.csv')
ipl.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# 3                            Wankhede Stadium      Mumbai        India
# 4                                Eden Gardens     Kolkata        India
#
#                    Toss_Winner                 match_winner Toss_Name  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders     field
# 1          Chennai Super Kings          Chennai Super Kings       bat
# 2             Rajasthan Royals             Delhi Daredevils       bat
# 3               Mumbai Indians  Royal Challengers Bangalore       bat
# 4              Deccan Chargers        Kolkata Knight Riders       bat
#
#   Win_Type Outcome_Type    ManOfMach  Win_Margin  Country_id
# 0     runs       Result  BB McCullum       140.0           1
# 1     runs       Result   MEK Hussey        33.0           1
# 2  wickets       Result  MF Maharoof         9.0           1
# 3  wickets       Result   MV Boucher         5.0           1
# 4  wickets       Result    DJ Hussey         5.0           1

# %%
ipl
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# ..        ...       ...                          ...
# 632       632   1082646             Delhi Daredevils
# 633       633   1082647               Mumbai Indians
# 634       634   1082648          Sunrisers Hyderabad
# 635       635   1082649               Mumbai Indians
# 636       636   1082650               Mumbai Indians
#
#                            Team2 match_date  Season_Year  \
# 0          Kolkata Knight Riders  4/18/2008         2008
# 1            Chennai Super Kings  4/19/2008         2008
# 2               Rajasthan Royals  4/19/2008         2008
# 3    Royal Challengers Bangalore  4/20/2008         2008
# 4                Deccan Chargers  4/20/2008         2008
# ..                           ...        ...          ...
# 632  Royal Challengers Bangalore  5/14/2017         2017
# 633      Rising Pune Supergiants  5/16/2017         2017
# 634        Kolkata Knight Riders  5/17/2017         2017
# 635        Kolkata Knight Riders  5/19/2017         2017
# 636      Rising Pune Supergiants  5/21/2017         2017
#
#                                      Venue_Name           City_Name  \
# 0                         M Chinnaswamy Stadium           Bangalore
# 1    Punjab Cricket Association Stadium, Mohali          Chandigarh
# 2                              Feroz Shah Kotla               Delhi
# 3                              Wankhede Stadium              Mumbai
# 4                                  Eden Gardens             Kolkata
# ..                                          ...                 ...
# 632                            Feroz Shah Kotla               Delhi
# 633                            Wankhede Stadium              Mumbai
# 634                       M Chinnaswamy Stadium           Bengaluru
# 635                       M Chinnaswamy Stadium           Bengaluru
# 636    Rajiv Gandhi International Stadium Uppal  Hyderabad (Deccan)
#
#     Country_Name                  Toss_Winner                 match_winner  \
# 0          India  Royal Challengers Bangalore        Kolkata Knight Riders
# 1          India          Chennai Super Kings          Chennai Super Kings
# 2          India             Rajasthan Royals             Delhi Daredevils
# 3          India               Mumbai Indians  Royal Challengers Bangalore
# 4          India              Deccan Chargers        Kolkata Knight Riders
# ..           ...                          ...                          ...
# 632        India  Royal Challengers Bangalore  Royal Challengers Bangalore
# 633        India               Mumbai Indians      Rising Pune Supergiants
# 634        India        Kolkata Knight Riders        Kolkata Knight Riders
# 635        India               Mumbai Indians               Mumbai Indians
# 636        India               Mumbai Indians               Mumbai Indians
#
#     Toss_Name Win_Type Outcome_Type         ManOfMach  Win_Margin  Country_id
# 0       field     runs       Result       BB McCullum       140.0           1
# 1         bat     runs       Result        MEK Hussey        33.0           1
# 2         bat  wickets       Result       MF Maharoof         9.0           1
# 3         bat  wickets       Result        MV Boucher         5.0           1
# 4         bat  wickets       Result         DJ Hussey         5.0           1
# ..        ...      ...          ...               ...         ...         ...
# 632       Bat     runs       Result          HV Patel        10.0           1
# 633     Field     runs       Result  Wasington Sundar        20.0           1
# 634     Field  wickets       Result   NM Coulter-Nile         7.0           1
# 635     Field  wickets       Result         KV Sharma         6.0           1
# 636       Bat      run       Result         KH Pandya         1.0           1
#
# [637 rows x 17 columns]

# %%
ipl.shape
# Out:
# (637, 17)

# %%
ipl['ManOfMach'].value_counts()
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# RG Sharma         14
#                   ..
# CL White           1
# JDP Oram           1
# AD Mascarenhas     1
# CR Brathwaite      1
# TL Suman           1
# Name: ManOfMach, Length: 202, dtype: int64

# %%
ipl['ManOfMach'].value_counts()[0:10]
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# RG Sharma         14
# SK Raina          14
# G Gambhir         13
# MS Dhoni          13
# AM Rahane         12
# MEK Hussey        12
# Name: ManOfMach, dtype: int64

# %%
ipl['ManOfMach'].value_counts()[0:5]
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# RG Sharma         14
# Name: ManOfMach, dtype: int64

# %%
list(ipl['ManOfMach'].value_counts()[0:5].keys())
# Out:
# ['CH Gayle', 'YK Pathan', 'AB de Villiers', 'DA Warner', 'RG Sharma']

# %%
plt.bar(list(ipl['ManOfMach'].value_counts()[0:5].keys()),list(ipl['ManOfMach'].value_counts()[0:5]),color='red')
plt.show()

# %%
ipl['Outcome_Type'].value_counts()
# Out:
# Result       626
# Superover      6
# No Result      3
# abandoned      1
# tied           1
# Name: Outcome_Type, dtype: int64

# %%
ipl['Toss_Winner'].value_counts()
# Out:
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Rising Pune Supergiants        12
# Kochi Tuskers Kerala            8
# Rising Pune Supergiant          1
# Name: Toss_Winner, dtype: int64

# %%
first_batting=ipl[ipl['Win_Type']!='wickets']

# %%
first_batting.head(10)
# Out:
#     Match_SK  match_id                        Team1  \
# 0          0    335987  Royal Challengers Bangalore
# 1          1    335988              Kings XI Punjab
# 7          7    335994          Chennai Super Kings
# 9          9    335996              Kings XI Punjab
# 14        14    336001  Royal Challengers Bangalore
# 16        16    336003             Delhi Daredevils
# 18        18    336005             Rajasthan Royals
# 21        21    336008              Kings XI Punjab
# 22        22    336009               Mumbai Indians
# 28        28    336015        Kolkata Knight Riders
#
#                           Team2 match_date  Season_Year  \
# 0         Kolkata Knight Riders  4/18/2008         2008
# 1           Chennai Super Kings  4/19/2008         2008
# 7                Mumbai Indians  4/23/2008         2008
# 9                Mumbai Indians  4/25/2008         2008
# 14          Chennai Super Kings  4/28/2008         2008
# 16  Royal Challengers Bangalore  4/30/2008         2008
# 18        Kolkata Knight Riders   5/1/2008         2008
# 21        Kolkata Knight Riders   5/3/2008         2008
# 22             Delhi Daredevils   5/4/2008         2008
# 28  Royal Challengers Bangalore   5/8/2008         2008
#
#                                     Venue_Name   City_Name Country_Name  \
# 0                        M Chinnaswamy Stadium   Bangalore        India
# 1   Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 7              MA Chidambaram Stadium, Chepauk     Chennai        India
# 9   Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 14                       M Chinnaswamy Stadium   Bangalore        India
# 16                            Feroz Shah Kotla       Delhi        India
# 18                      Sawai Mansingh Stadium      Jaipur        India
# 21  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 22                  Dr DY Patil Sports Academy      Mumbai        India
# 28                                Eden Gardens     Kolkata        India
#
#                     Toss_Winner           match_winner Toss_Name Win_Type  \
# 0   Royal Challengers Bangalore  Kolkata Knight Riders     field     runs
# 1           Chennai Super Kings    Chennai Super Kings       bat     runs
# 7                Mumbai Indians    Chennai Super Kings     field     runs
# 9                Mumbai Indians        Kings XI Punjab     field     runs
# 14          Chennai Super Kings    Chennai Super Kings       bat     runs
# 16  Royal Challengers Bangalore       Delhi Daredevils     field     runs
# 18             Rajasthan Royals       Rajasthan Royals       bat     runs
# 21              Kings XI Punjab        Kings XI Punjab       bat     runs
# 22             Delhi Daredevils         Mumbai Indians     field     runs
# 28        Kolkata Knight Riders  Kolkata Knight Riders       bat     runs
#
#    Outcome_Type      ManOfMach  Win_Margin  Country_id
# 0        Result    BB McCullum       140.0           1
# 1        Result     MEK Hussey        33.0           1
# 7        Result      ML Hayden         6.0           1
# 9        Result  KC Sangakkara        66.0           1
# 14       Result       MS Dhoni        13.0           1
# 16       Result     GD McGrath        10.0           1
# 18       Result    SA Asnodkar        45.0           1
# 21       Result      IK Pathan         9.0           1
# 22       Result     SM Pollock        29.0           1
# 28       Result     SC Ganguly         5.0           1

# %%
plt.figure(figsize=(6,6))
plt.hist(first_batting['Win_Margin'])
plt.xlabel("Runs")
plt.title("Distribution of Runs")
plt.show()
# Out:
# C:\Users\SHAIK KAREEM FAROOQ\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\SHAIK KAREEM FAROOQ\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
first_batting['match_winner'].value_counts()
# Out:
# Mumbai Indians                 47
# Chennai Super Kings            46
# Kings XI Punjab                34
# Royal Challengers Bangalore    31
# Kolkata Knight Riders          31
# Rajasthan Royals               25
# Sunrisers Hyderabad            24
# Delhi Daredevils               21
# Deccan Chargers                18
# Rising Pune Supergiants         7
# Pune Warriors                   6
# Kochi Tuskers Kerala            2
# abandoned                       1
# tied                            1
# Gujarat Lions                   1
# Name: match_winner, dtype: int64

# %%
ipl['match_winner'].value_counts()
# Out:
# Mumbai Indians                 91
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Rising Pune Supergiants        15
# Gujarat Lions                  13
# Pune Warriors                  12
# Kochi Tuskers Kerala            6
# abandoned                       1
# tied                            1
# Name: match_winner, dtype: int64

# %%
list(ipl['match_winner'].value_counts()[0:5])
# Out:
# [91, 79, 77, 73, 70]

# %%
list(ipl['match_winner'].value_counts()[0:5].keys())
# Out:
# ['Mumbai Indians',
#  'Chennai Super Kings',
#  'Kolkata Knight Riders',
#  'Royal Challengers Bangalore',
#  'Kings XI Punjab']

# %%
plt.figure(figsize=(10,6))
plt.plot(list(ipl['match_winner'].value_counts()[0:5].keys()),list(ipl['match_winner'].value_counts()[0:5]))
plt.xlabel("IPL teams")
plt.ylabel("No.of matchs")
plt.title("IPL TOP 5 TEAMS")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(list(ipl['match_winner'].value_counts()[0:3].keys()),list(ipl['match_winner'].value_counts()[0:3]),color=["blue","yellow","violet"])
plt.xlabel("IPL teams")
plt.ylabel("No.of matchs")
plt.title("IPL TOP 5 TEAMS")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.pie(list(ipl['match_winner'].value_counts()),labels=list(ipl['match_winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
second_batting=ipl[ipl['Win_Type']!='runs']
second_batting.head()
# Out:
#    Match_SK  match_id                  Team1                        Team2  \
# 2         2    335989       Delhi Daredevils             Rajasthan Royals
# 3         3    335990         Mumbai Indians  Royal Challengers Bangalore
# 4         4    335991  Kolkata Knight Riders              Deccan Chargers
# 5         5    335992       Rajasthan Royals              Kings XI Punjab
# 6         6    335993        Deccan Chargers             Delhi Daredevils
#
#   match_date  Season_Year                                 Venue_Name  \
# 2  4/19/2008         2008                           Feroz Shah Kotla
# 3  4/20/2008         2008                           Wankhede Stadium
# 4  4/20/2008         2008                               Eden Gardens
# 5  4/21/2008         2008                     Sawai Mansingh Stadium
# 6  4/22/2008         2008  Rajiv Gandhi International Stadium, Uppal
#
#    City_Name Country_Name       Toss_Winner                 match_winner  \
# 2      Delhi        India  Rajasthan Royals             Delhi Daredevils
# 3     Mumbai        India    Mumbai Indians  Royal Challengers Bangalore
# 4    Kolkata        India   Deccan Chargers        Kolkata Knight Riders
# 5     Jaipur        India   Kings XI Punjab             Rajasthan Royals
# 6  Hyderabad        India   Deccan Chargers             Delhi Daredevils
#
#   Toss_Name Win_Type Outcome_Type    ManOfMach  Win_Margin  Country_id
# 2       bat  wickets       Result  MF Maharoof         9.0           1
# 3       bat  wickets       Result   MV Boucher         5.0           1
# 4       bat  wickets       Result    DJ Hussey         5.0           1
# 5       bat  wickets       Result    SR Watson         6.0           1
# 6       bat  wickets       Result     V Sehwag         9.0           1

# %%
plt.hist(second_batting['Win_Margin'],bins=30)
plt.show()
# Out:
# C:\Users\SHAIK KAREEM FAROOQ\anaconda3\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\SHAIK KAREEM FAROOQ\anaconda3\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
second_batting['match_winner'].value_counts()
# Out:
# Kolkata Knight Riders          46
# Mumbai Indians                 45
# Royal Challengers Bangalore    43
# Delhi Daredevils               41
# Rajasthan Royals               40
# Kings XI Punjab                38
# Chennai Super Kings            33
# Sunrisers Hyderabad            19
# Gujarat Lions                  12
# Deccan Chargers                11
# Rising Pune Supergiants         8
# Pune Warriors                   6
# Kochi Tuskers Kerala            4
# abandoned                       1
# tied                            1
# Name: match_winner, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.bar(list(second_batting['match_winner'].value_counts().keys()[0:4]),list(second_batting['match_winner'].value_counts()[0:4]),color=["red","green","yellow","blue"])
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(second_batting['match_winner'].value_counts()),labels=list(second_batting['match_winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
ipl['Season_Year'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2017    60
# 2016    60
# 2014    60
# 2010    60
# 2015    59
# 2008    58
# 2009    57
# Name: Season_Year, dtype: int64

# %%
ipl['City_Name'].value_counts()
# Out:
# Mumbai                85
# Kolkata               61
# Delhi                 60
# Bangalore             58
# Chennai               48
# Chandigarh            42
# Hyderabad             41
# Jaipur                33
# Pune                  32
# Abu Dhabi             20
# Durban                15
# Centurion             12
# Ahmedabad             12
# Visakhapatnam         11
# Rajkot                10
# Dharamsala             9
# Bengaluru              9
# Johannesburg           8
# Hyderabad (Deccan)     8
# Port Elizabeth         7
# Ranchi                 7
# Cuttack                7
# Cape Town              7
# Raipur                 6
# Indore                 5
# Kochi                  5
# Kanpur                 4
# Mohali                 4
# East London            3
# Nagpur                 3
# Kimberley              3
# Bloemfontein           2
# Name: City_Name, dtype: int64

# %%
import numpy as np

# %%
np.sum(ipl['Toss_Winner']==ipl['match_winner'])
# Out:
# 324

# %%
324/637
# Out:
# 0.5086342229199372

# %%
BBB=pd.read_csv('F:\Ball_By_Ball.csv')
BBB.head()
# Out:
#    MatcH_id  Over_id  Ball_id  Innings_No Team_Batting Team_Bowling  \
# 0    598028       15        6           1            5            2
# 1    598028       14        1           1            5            2
# 2    598028       14        2           1            5            2
# 3    598028       14        3           1            5            2
# 4    598028       14        4           1            5            2
#
#    Striker_Batting_Position Extra_Type  Runs_Scored  Extra_runs  ...  \
# 0                       6.0  No Extras            4           0  ...
# 1                       5.0  No Extras            1           0  ...
# 2                       3.0  No Extras            1           0  ...
# 3                       5.0  No Extras            1           0  ...
# 4                       3.0  No Extras            0           0  ...
#
#    Fielder_match_SK  Fielder_SK  Bowler_match_SK  BOWLER_SK  \
# 0                -1          -1            20343         82
# 1                -1          -1            20348        345
# 2                -1          -1            20348        345
# 3                -1          -1            20348        345
# 4                -1          -1            20348        345
#
#    PlayerOut_match_SK  BattingTeam_SK BowlingTeam_SK  Keeper_Catch  \
# 0                  -1               4              1             0
# 1                  -1               4              1             0
# 2                  -1               4              1             0
# 3                  -1               4              1             0
# 4                  -1               4              1             0
#
#    Player_out_sk  MatchDateSK
# 0              0     20130420
# 1              0     20130420
# 2              0     20130420
# 3              0     20130420
# 4              0     20130420
#
# [5 rows x 48 columns]

# %%
BBB
# Out:
#         MatcH_id  Over_id  Ball_id  Innings_No Team_Batting Team_Bowling  \
# 0         598028       15        6           1            5            2
# 1         598028       14        1           1            5            2
# 2         598028       14        2           1            5            2
# 3         598028       14        3           1            5            2
# 4         598028       14        4           1            5            2
# ...          ...      ...      ...         ...          ...          ...
# 150446    598028       15        1           1            5            2
# 150447    598028       15        2           1            5            2
# 150448    598028       15        3           1            5            2
# 150449    598028       15        4           1            5            2
# 150450    598028       15        5           1            5            2
#
#         Striker_Batting_Position Extra_Type  Runs_Scored  Extra_runs  ...  \
# 0                            6.0  No Extras            4           0  ...
# 1                            5.0  No Extras            1           0  ...
# 2                            3.0  No Extras            1           0  ...
# 3                            5.0  No Extras            1           0  ...
# 4                            3.0  No Extras            0           0  ...
# ...                          ...        ...          ...         ...  ...
# 150446                       5.0  No Extras            1           0  ...
# 150447                       3.0  No Extras            2           0  ...
# 150448                       3.0  No Extras            4           0  ...
# 150449                       3.0  No Extras            0           0  ...
# 150450                       6.0  No Extras            0           0  ...
#
#         Fielder_match_SK  Fielder_SK  Bowler_match_SK  BOWLER_SK  \
# 0                     -1          -1            20343         82
# 1                     -1          -1            20348        345
# 2                     -1          -1            20348        345
# 3                     -1          -1            20348        345
# 4                     -1          -1            20348        345
# ...                  ...         ...              ...        ...
# 150446                -1          -1            20343         82
# 150447                -1          -1            20343         82
# 150448                -1          -1            20343         82
# 150449             20349         348            20343         82
# 150450                -1          -1            20343         82
#
#         PlayerOut_match_SK  BattingTeam_SK BowlingTeam_SK  Keeper_Catch  \
# 0                       -1               4              1             0
# 1                       -1               4              1             0
# 2                       -1               4              1             0
# 3                       -1               4              1             0
# 4                       -1               4              1             0
# ...                    ...             ...            ...           ...
# 150446                  -1               4              1             0
# 150447                  -1               4              1             0
# 150448                  -1               4              1             0
# 150449               20328               4              1             0
# 150450                  -1               4              1             0
#
#         Player_out_sk  MatchDateSK
# 0                   0     20130420
# 1                   0     20130420
# 2                   0     20130420
# 3                   0     20130420
# 4                   0     20130420
# ...               ...          ...
# 150446              0     20130420
# 150447              0     20130420
# 150448              0     20130420
# 150449              0     20130420
# 150450              0     20130420
#
# [150451 rows x 48 columns]

# %%
BBB['MatcH_id'].unique()
# Out:
# array([ 598028,  598063,  598031,  829720,  829782,  829774,  829726,
#         392241,  392244,  392193,  392201,  392214,  392234,  392221,
#         392210,  392225,  829732,  829792,  829744,  829766,  829762,
#         548365,  548372,  548311,  548384,  548360,  548339,  548344,
#         548322,  548382,  548330,  548347,  501267,  501237,  501233,
#         501231,  501207,  501253,  501240,  501218,  501223,  501246,
#         501255,  980954,  980916,  980980,  981006,  980942,  981018,
#         980992,  980960,  980910,  980966,  980950,  980930,  980968,
#         980982,  981004,  980918,  980976,  980946,  980990,  980940,
#         501235,  501272,  501274,  501208,  501244,  501224,  501247,
#         501227,  501260,  336016,  335995,  336022,  336003,  336031,
#         336006,  336014,  336027,  336000,  336043,  729314,  729322,
#         734006,  734020,  734042,  734026,  733982,  729316,  734034,
#         729300,  392206,  392228,  392242,  392197,  392217,  419114,
#         419153,  419118,  419158,  734032,  729304,  734040,  734018,
#         729318,  733996,  729310,  734004,  734010,  598019,  598057,
#         598006,  598054,  598068,  598077,  598024,  598014,  548351,
#         548319,  548313,  548356,  548340,  548381,  548361,  548316,
#         548357,  501264,  501212,  548320,  548349,  548352,  548373,
#         548386,  548328, 1082632, 1082640, 1082597,  501216,  501273,
#         501271,  501276,  501265,  501249,  335989,  336020,  336009,
#         336037,  335993,  336025,  336002,  336026,  335990,  336017,
#         501257,  501232,  501210, 1082644, 1082649, 1082602, 1082628,
#        1082612, 1082641, 1082614,  829818,  829712,  829806,  829730,
#         829772,  829752,  829788,  419132,  419144,  419163,  419123,
#         419149,  419136,  419166,  419127,  419111, 1082629,  980922,
#         980996,  980924,  981010,  980956,  980908,  734012,  729290,
#         733994,  729306,  733998,  829718,  829776,  829770,  980926,
#         981016,  981012,  980934,  980972,  981022, 1082617,  729286,
#         733988,  729292,  733976,  734028,  548364,  548371,  336023,
#         335994,  335996,  336033,  336013,  336041,  335999,  548333,
#         548325,  548317,  548312,  548383,  548362,  548368,  548375,
#         548331,  548378,  548334,  501275,  501213,  501205,  501252,
#         501250,  501203,  548326,  598052,  598076,  598070,  598037,
#         598003,  598045,  598022,  598059,  598025,  598067,  419140,
#         419138,  419128,  419117,  419141,  419120,  419159,  829798,
#         829736,  829710,  829810,  829742,  829800,  829822,  829828,
#         829794,  336029,  336019,  335991,  336007,  336039,  336012,
#         336042,  336004,  336036, 1082635, 1082600, 1082638, 1082592,
#        1082618, 1082647, 1082650, 1082625, 1082606,  548358,  548380,
#         501211,  501245,  501254,  501258,  501226,  501241,  501220,
#         501266,  548323,  548336,  548355,  548341,  548329,  829728,
#         829738,  829796,  829816,  548353,  548346,  419145,  419133,
#         419167,  419124,  419162,  419169,  419156,  419150,  548332,
#         548367,  548335,  548327,  548324,  829748,  598064,  598033,
#         598011,  598029,  598072,  598040,  729288,  734052,  733992,
#         729302,  734008,  729298,  733986,  729308,  734000,  734050,
#         392204,  392226,  392236,  980938,  980998,  981008,  980988,
#         980970,  981002, 1082636, 1082601, 1082639, 1082608, 1082622,
#        1082604,  501239,  501225,  419126,  419164,  419134,  419142,
#         419160,  419121,  548315,  548377,  829734,  829722,  829780,
#         548318,  548370,  548363,  548342,  548338,  392212,  392191,
#         392195,  392238,  392224,  392216,  392208,  392202,  392189,
#         829820,  829756,  598015,  598049,  598055,  598034,  598004,
#         598038,  598007,  598051,  829786,  829750,  829784,  829826,
#         729312,  734048,  734054,  734002,  829790,  829808,  829754,
#         829768,  501262,  501228,  501256,  501242,  501217,  501269,
#         419170,  419147,  419130,  419168,  419115,  419152,  501259,
#        1082627, 1082648, 1082591, 1082609, 1082623, 1082630,  980952,
#         548348,  548376,  548337,  548366,  392233,  335987,  336015,
#         336030,  335998,  336040,  336008,  336005,  336032,  336021,
#         336011,  336044,  335988,  336018,  336024,  335992,  336038,
#         335997,  336028,  336045,  392227,  392205,  392230,  392240,
#         392220,  336001,  336034,  336010,  501263,  501230,  501238,
#         501243,  501215,  501234,  733978,  734030,  734022,  734046,
#         734036, 1082646, 1082605, 1082626, 1082611, 1082599, 1082642,
#         392190,  392229,  392243,  392196,  392209,  392187,  548321,
#         980914,  980932,  980986,  598062,  598013,  598027,  598039,
#         598036,  598021,  598048,  598010, 1082631, 1082620, 1082613,
#        1082593, 1082633, 1082598,  598075,  598078,  598042,  598071,
#         829812,  829724,  829716,  829778,  829804,  829764,  419129,
#         419148,  419154,  419113,  419151,  419137,  501219,  501214,
#         501209,  501236,  501268,  501204,  392218,  392199,  392237,
#         392213,  392223,  729296,  734038,  734044,  734024,  829824,
#         548369,  548385,  598058,  598066,  598074,  598018,  419122,
#         419161,  980928,  980978,  980906,  980962,  980920,  981014,
#         392239,  392219,  392207,  392222,  392211,  981020,  598016,
#         598060,  598044,  598065,  598047,  598032,  598020, 1082615,
#        1082634, 1082596, 1082643, 1082624, 1082595,  548359,  548314,
#         548374,  548379, 1082607, 1082621, 1082610,  729320,  733984,
#         981000,  980964,  829758,  829814,  829740,  829802,  419116,
#         419139,  419112,  419155,  419146,  392194,  392186,  392232,
#         419131,  598017,  598073,  598050,  598069,  598041,  501206,
#         501251,  501221,  501248,  501270,  598043,  598008,  598030,
#         981024,  980912,  980958,  392215,  392200,  392188,  392231,
#         734016,  733980,  729294,  598009,  598053,  980944,  980994,
#        1082594, 1082645,  548350,  548354,  419119,  419157,  419125,
#         419165,  598005,  598023,  598056,  598035,  501261,  501229,
#         598012,  598046,  733990,  392203,  392235,  980948,  980984,
#         980936,  980974,  829746,  829714,  598026,  598061, 1082616,
#        1082637,  419135,  419143, 1082603,  729284,  734014], dtype=int64)

# %%
match_1=BBB[BBB['MatcH_id']==598028]
match_1.head()
# Out:
#    MatcH_id  Over_id  Ball_id  Innings_No Team_Batting Team_Bowling  \
# 0    598028       15        6           1            5            2
# 1    598028       14        1           1            5            2
# 2    598028       14        2           1            5            2
# 3    598028       14        3           1            5            2
# 4    598028       14        4           1            5            2
#
#    Striker_Batting_Position Extra_Type  Runs_Scored  Extra_runs  ...  \
# 0                       6.0  No Extras            4           0  ...
# 1                       5.0  No Extras            1           0  ...
# 2                       3.0  No Extras            1           0  ...
# 3                       5.0  No Extras            1           0  ...
# 4                       3.0  No Extras            0           0  ...
#
#    Fielder_match_SK  Fielder_SK  Bowler_match_SK  BOWLER_SK  \
# 0                -1          -1            20343         82
# 1                -1          -1            20348        345
# 2                -1          -1            20348        345
# 3                -1          -1            20348        345
# 4                -1          -1            20348        345
#
#    PlayerOut_match_SK  BattingTeam_SK BowlingTeam_SK  Keeper_Catch  \
# 0                  -1               4              1             0
# 1                  -1               4              1             0
# 2                  -1               4              1             0
# 3                  -1               4              1             0
# 4                  -1               4              1             0
#
#    Player_out_sk  MatchDateSK
# 0              0     20130420
# 1              0     20130420
# 2              0     20130420
# 3              0     20130420
# 4              0     20130420
#
# [5 rows x 48 columns]

# %%
match_1.shape
# Out:
# (232, 48)

# %%
RR=match_1[match_1['Innings_No']==1]

# %%
RR.head()
# Out:
#    MatcH_id  Over_id  Ball_id  Innings_No Team_Batting Team_Bowling  \
# 0    598028       15        6           1            5            2
# 1    598028       14        1           1            5            2
# 2    598028       14        2           1            5            2
# 3    598028       14        3           1            5            2
# 4    598028       14        4           1            5            2
#
#    Striker_Batting_Position Extra_Type  Runs_Scored  Extra_runs  ...  \
# 0                       6.0  No Extras            4           0  ...
# 1                       5.0  No Extras            1           0  ...
# 2                       3.0  No Extras            1           0  ...
# 3                       5.0  No Extras            1           0  ...
# 4                       3.0  No Extras            0           0  ...
#
#    Fielder_match_SK  Fielder_SK  Bowler_match_SK  BOWLER_SK  \
# 0                -1          -1            20343         82
# 1                -1          -1            20348        345
# 2                -1          -1            20348        345
# 3                -1          -1            20348        345
# 4                -1          -1            20348        345
#
#    PlayerOut_match_SK  BattingTeam_SK BowlingTeam_SK  Keeper_Catch  \
# 0                  -1               4              1             0
# 1                  -1               4              1             0
# 2                  -1               4              1             0
# 3                  -1               4              1             0
# 4                  -1               4              1             0
#
#    Player_out_sk  MatchDateSK
# 0              0     20130420
# 1              0     20130420
# 2              0     20130420
# 3              0     20130420
# 4              0     20130420
#
# [5 rows x 48 columns]

# %%
RR['Runs_Scored'].value_counts()
# Out:
# 0    59
# 1    37
# 4    14
# 2     6
# 6     2
# Name: Runs_Scored, dtype: int64

# %%
RCB=match_1[match_1['Innings_No']==2]

# %%
RCB
# Out:
#        MatcH_id  Over_id  Ball_id  Innings_No Team_Batting Team_Bowling  \
# 97462    598028        3        3           2            2            5
# 97463    598028        3        4           2            2            5
# 97464    598028        3        5           2            2            5
# 97465    598028        3        6           2            2            5
# 97466    598028        3        7           2            2            5
# ...         ...      ...      ...         ...          ...          ...
# 97696    598028        2        4           2            2            5
# 97697    598028        2        5           2            2            5
# 97698    598028        2        6           2            2            5
# 97699    598028        3        1           2            2            5
# 97700    598028        3        2           2            2            5
#
#        Striker_Batting_Position Extra_Type  Runs_Scored  Extra_runs  ...  \
# 97462                       2.0  No Extras            0           0  ...
# 97463                       2.0      wides            0           1  ...
# 97464                       2.0  No Extras            0           0  ...
# 97465                       2.0  No Extras            1           0  ...
# 97466                       1.0  No Extras            1           0  ...
# ...                         ...        ...          ...         ...  ...
# 97696                       1.0  No Extras            0           0  ...
# 97697                       1.0  No Extras            4           0  ...
# 97698                       1.0  No Extras            4           0  ...
# 97699                       2.0      wides            0           1  ...
# 97700                       2.0  No Extras            4           0  ...
#
#        Fielder_match_SK  Fielder_SK  Bowler_match_SK  BOWLER_SK  \
# 97462                -1          -1            20334        237
# 97463                -1          -1            20334        237
# 97464                -1          -1            20334        237
# 97465                -1          -1            20334        237
# 97466                -1          -1            20334        237
# ...                 ...         ...              ...        ...
# 97696                -1          -1            20331         76
# 97697                -1          -1            20331         76
# 97698                -1          -1            20331         76
# 97699                -1          -1            20334        237
# 97700                -1          -1            20334        237
#
#        PlayerOut_match_SK  BattingTeam_SK BowlingTeam_SK  Keeper_Catch  \
# 97462                  -1               1              4             0
# 97463                  -1               1              4             0
# 97464                  -1               1              4             0
# 97465                  -1               1              4             0
# 97466                  -1               1              4             0
# ...                   ...             ...            ...           ...
# 97696                  -1               1              4             0
# 97697                  -1               1              4             0
# 97698                  -1               1              4             0
# 97699                  -1               1              4             0
# 97700                  -1               1              4             0
#
#        Player_out_sk  MatchDateSK
# 97462              0     20130420
# 97463              0     20130420
# 97464              0     20130420
# 97465              0     20130420
# 97466              0     20130420
# ...              ...          ...
# 97696              0     20130420
# 97697              0     20130420
# 97698              0     20130420
# 97699              0     20130420
# 97700              0     20130420
#
# [114 rows x 48 columns]

# %%
RCB['Runs_Scored'].value_counts()
# Out:
# 0    57
# 1    39
# 4    12
# 2     4
# 6     2
# Name: Runs_Scored, dtype: int64
